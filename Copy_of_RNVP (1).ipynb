# %%
from os import stat_result
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn import cluster, datasets, mixture
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from pylab import rcParams
rcParams['figure.figsize'] = 8, 10
rcParams['figure.dpi'] = 300

# %%
def checkerboard(height, width, r=False):
    """
    Takes in the dimensions of the checkerboard mask to be produced.
    Will output a 2D tf tensor containing a checkerboard pattern of 1s and 0s.
    """
    checkerboard = [[(i + j) % 2 for j in range(width)] for i in range(height)]
    return tf.convert_to_tensor(checkerboard, dtype='float32')

# %%
class RNVP(tf.keras.Model):
    def __init__(self, depth, height, prior_dim, hidden_size):
        super(RNVP, self).__init__()

        """
        Takes in the depth of each component network in the Model (depth) as well as the dimension of the density we're estimating (prior_dim).
        The structure of the Model has four main components, the mask, the prior, the t-network and the s-network.
        In init we construct each of these according to the specifications described by height, depth and prior_dim
        
        Inputs:
          depth: number of layers in each network of s and t
          height: number of transformations (ie, height of mask/ number of networks in s and t)
          prior_dim: dimension size of input data points 
        """
        ## Construct prior
        ## We assume for simplicity the prior is a MVN of the same dimension as the input data
        self.prior = tfp.distributions.MultivariateNormalTriL(loc=tf.zeros(prior_dim), scale_tril=tf.eye(prior_dim))
        ## Construct mask
        self.height = height 
        self.mask = checkerboard(self.height,prior_dim)
        ## Initialize t and s network lists
        ## The number of networks in the list should be the same as the number of rows in mask
        ## Each network should have number of layers = depth, the last layer in each s network should have tanh activation
        self.t = []
        self.s = []
        for i in range (self.height):
          self.t.append(Sequential())
          self.s.append(Sequential())
        self.hidden_size = hidden_size
        ## Fill each network in both network lists
        for j in range(self.height):
            for i in range(depth-1):
                self.t[j].add(tf.keras.layers.Dense(
                    self.hidden_size,
                    activation= tf.keras.layers.LeakyReLU(alpha=0.01),
                    kernel_initializer= 'uniform',
                    bias_initializer= 'uniform'))
                self.s[j].add(tf.keras.layers.Dense(
                    self.hidden_size,
                    activation= tf.keras.layers.LeakyReLU(alpha=0.01),
                    kernel_initializer= 'uniform',
                    bias_initializer= 'uniform'))
            self.t[j].add(tf.keras.layers.Dense(
                prior_dim,
                kernel_initializer= 'uniform',
                bias_initializer= 'uniform'))
            self.s[j].add(tf.keras.layers.Dense(
                prior_dim,
                activation='tanh',
                kernel_initializer= 'uniform',
                bias_initializer= 'uniform'))


    def call(self, x):
        """
        When the layers have been fully learned, this call will transform data from an arbitrary
        distribution to data from a multivariate normal distribution in an invertible way 

        Inputs:
            x: A sample distribution of size (num_samples x prior_dim)
        Returns:
            output_dist: forward transform of x, what the original distribution looks like in the latent space (prior distribution)
            sldj: the log determinant of the Jacobian for the s network layers
        """
        ## Initialize our output_dist as our input_dist x, we will iteratively update it until it looks normal
        output_dist = x
        num_samples = x.shape[0]
        sldj = tf.zeros([num_samples])
        ## Loop through each row in the mask and each network in t and s 
        for i in range(self.height):
            ## Mask and reverse mask will each be of shape (prior_dim)
            mask = self.mask[i]
            reverse_mask = 1 - mask
            ## The variables s and t in the loop will be networks with number of layers = depth
            s = self.s[i]
            t = self.t[i]
            ## First apply the forward mask to output_dist
            ## output_dist_masked will have the same shape as output_dist (num_samples x prior_dim)
            output_dist_masked = mask * output_dist
            ## Pass this through s and t and subsequently apply reverse mask
            ## s_out and t_out will be of size (num_samples x prior_dim)
            s_out = s(output_dist_masked)* reverse_mask
            t_out = t(output_dist_masked)* reverse_mask
            ## Update output_dist via the transformation described in equation (8) of this paper https://arxiv.org/pdf/1605.08803.pdf
            ## We add the un-updated output_dist_masked to the updated output_dist multiplied by the reverse mask 
            updated_dist = (output_dist-t_out) * tf.math.exp(-1 * s_out)
            output_dist = output_dist_masked + reverse_mask * updated_dist
            ## We also update the log of the determinant of the Jacobian at each step of the transformation according
            ## to equation (6) from the same paper. Note we are subtracting away instead of adding because we are looking at the reverse transformation
            ## of the one described in the paper. We still want to maximize this sldj value even though it's negative
            sldj -= tf.math.reduce_sum(s_out, axis=1)

        return output_dist, sldj


    def loss_function(self, output_dist, sldj):
        """
        By the change of variable theory, computing the density on a point x is accomplished by
        computing the density of its image f(x) and multiplying by the associated Jacobian determinant
        of the transformation (3) | we can thus define our negative log likelihood (which we hope to minimize)
        as the average of our sldj output subtracted out from the negative prior log probability of the output distribution

        Inputs:
            output_dist: latent space distribution 
            sldj: negative log of the determinant of the jacobian of the transformation 
        Returns:
            loss: average negative log likelihood as described above
        """
        ## Negative prior log probability of the output distribution
        npp = -self.prior.log_prob(output_dist)
        ## Subtract out log determinant of jacobian 
        nlls = npp - sldj
        ## Average and return

        return tf.reduce_mean(nlls)

  
    def sample (self, num_samples):
      """
        This function performs the inverse operation of call, so that once the transformation layers
        have been fully learned you will be able to generate num_samples data points from the prior 
        (via simple sampling) and then transform those points to the desired distribution we've learned
        This offers a quick and efficient way of sampling from arbitrarily complex distributions so long as they've been
        learned by the model.  

        Inputs:
            num_samples: the number of sample points you want to generate
        Returns:
            input_dist: a sampled distribution of points from the input space of size num_samples
        """
      ## Randomly sample from prior
      input_dist = self.prior.sample([num_samples])
      ## Run inverse transformation (ie do the steps in call but backwards)
      for i in reversed(range(self.height)):
        ## Mask and reverse mask will each be of shape (prior_dim)
        mask = self.mask[i]
        reverse_mask = 1 - mask
        ## The variables s and t in the loop will be networks with number of layers = depth
        s = self.s[i]
        t = self.t[i]
        ## First apply the forward mask to input_dist
        input_dist_masked = mask * input_dist
        ## Pass this through s and t and subsequently apply reverse mask
        s_out = s(input_dist_masked)* reverse_mask
        t_out = t(input_dist_masked)* reverse_mask
        ## Update input_dist via the transformation described in equation (7) of this paper https://arxiv.org/pdf/1605.08803.pdf
        input_dist = input_dist_masked + reverse_mask * (t_out + input_dist * tf.math.exp(s_out))

      return input_dist

# %%
flow = RNVP(depth = 3, height = 6, prior_dim = 2, hidden_size = 256)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
for t in range(5001):   
    moons = datasets.make_moons(n_samples=100, noise=.05)[0].astype(np.float32)
    with tf.GradientTape() as tape:
      z, sldj = flow.call(tf.convert_to_tensor(moons))
      loss = flow.loss_function(z, sldj)
    gradients = tape.gradient(loss, flow.trainable_variables)
    optimizer.apply_gradients(zip(gradients, flow.trainable_variables))
    
    if t % 200 == 0:
        print('iter %s:' % t, 'loss = %.3f' % loss)
# Out:
# iter 0: loss = 2.423
# iter 200: loss = 1.574
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-7fe69124feec> in <module>()
#       6       loss = flow.loss_function(z, sldj)
#       7     gradients = tape.gradient(loss, flow.trainable_variables)
# ----> 8     optimizer.apply_gradients(zip(gradients, flow.trainable_variables))
#       9
#      10     if t % 200 == 0:
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in trainable_variables(self)
#    2306   @doc_controls.do_not_generate_docs
#    2307   def trainable_variables(self):
# -> 2308     return self.trainable_weights
#    2309
#    2310   @property
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in trainable_weights(self)
#    2102     trainable_variables = []
#    2103     for trackable_obj in self._self_tracked_trackables:
# -> 2104       trainable_variables += trackable_obj.trainable_variables
#    2105     trainable_variables += self._trainable_weights
#    2106     return self._dedup_weights(trainable_variables)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/module/module.py in trainable_variables(self)
#     174     """
#     175     return tuple(
# --> 176         self._flatten(predicate=_is_trainable_variable, expand_composites=True))
#     177
#     178   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/module/module.py in _flatten_module(module, recursive, predicate, attribute_traversal_key, attributes_to_ignore, with_path, expand_composites, module_path, seen, recursion_stack)
#     409     try:
#     410       leaves = nest.flatten_with_tuple_paths(
# --> 411           prop, expand_composites=expand_composites)
#     412     except Exception as cause:  # pylint: disable=broad-except
#     413       six.raise_from(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in flatten_with_tuple_paths(structure, expand_composites)
#    1642   return list(zip(yield_flat_paths(structure,
#    1643                                    expand_composites=expand_composites),
# -> 1644                   flatten(structure, expand_composites=expand_composites)))
#    1645
#    1646
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in yield_flat_paths(nest, expand_composites)
#    1588   """
#    1589   is_seq = is_sequence_or_composite if expand_composites else is_sequence
# -> 1590   for k, _ in _yield_flat_up_to(nest, nest, is_seq):
#    1591     yield k
#    1592
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in _yield_flat_up_to(shallow_tree, input_tree, is_seq, path)
#     972     yield (path, input_tree)
#     973   else:
# --> 974     input_tree = dict(_yield_sorted_items(input_tree))
#     975     for shallow_key, shallow_subtree in _yield_sorted_items(shallow_tree):
#     976       subpath = path + (shallow_key,)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in _yield_sorted_items(iterable)
#     254       yield field, getattr(iterable, field)
#     255   elif _is_composite_tensor(iterable):
# --> 256     type_spec = iterable._type_spec  # pylint: disable=protected-access
#     257     yield type_spec.value_type.__name__, type_spec._to_components(iterable)  # pylint: disable=protected-access
#     258   elif _is_type_spec(iterable):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/internal/auto_composite_tensor.py in _type_spec(obj)
#     607     def _type_spec(obj):
#     608       return _AlreadyCTTypeSpec.from_instance(
# --> 609           obj, omit_kwargs, non_identifying_kwargs)
#     610
#     611     cls._type_spec = property(_type_spec)  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/internal/auto_composite_tensor.py in from_instance(cls, instance, omit_kwargs, non_identifying_kwargs)
#     245     for k, v in list(kwargs.items()):
#     246       # If v contains no Tensors, this will just be v
# --> 247       type_spec_or_v = _extract_type_spec_recursively(v)
#     248       if type_spec_or_v is not v:
#     249         param_specs[k] = type_spec_or_v
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/internal/auto_composite_tensor.py in _extract_type_spec_recursively(value)
#     147     return tf.TensorSpec(value.shape, value.dtype)
#     148   if isinstance(value, (list, tuple)):
# --> 149     specs = [_extract_type_spec_recursively(v) for v in value]
#     150     was_tensor = list([a is not b for a, b in zip(value, specs)])
#     151     has_tensors = any(was_tensor)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/internal/auto_composite_tensor.py in <listcomp>(.0)
#     147     return tf.TensorSpec(value.shape, value.dtype)
#     148   if isinstance(value, (list, tuple)):
# --> 149     specs = [_extract_type_spec_recursively(v) for v in value]
#     150     was_tensor = list([a is not b for a, b in zip(value, specs)])
#     151     has_tensors = any(was_tensor)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/internal/auto_composite_tensor.py in _extract_type_spec_recursively(value)
#     140   """
#     141   if isinstance(value, composite_tensor.CompositeTensor):
# --> 142     return value._type_spec  # pylint: disable=protected-access
#     143   if isinstance(value, tf.Variable):
#     144     return resource_variable_ops.VariableSpec(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/internal/auto_composite_tensor.py in _type_spec(obj)
#     607     def _type_spec(obj):
#     608       return _AlreadyCTTypeSpec.from_instance(
# --> 609           obj, omit_kwargs, non_identifying_kwargs)
#     610
#     611     cls._type_spec = property(_type_spec)  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/internal/auto_composite_tensor.py in from_instance(cls, instance, omit_kwargs, non_identifying_kwargs)
#     236                        f'`{type(instance).__name__}.`')
#     237     prefer_static_value = tuple(
# --> 238         getattr(instance, '_composite_tensor_shape_params', ()))
#     239     kwargs = _extract_init_kwargs(instance, omit_kwargs=omit_kwargs,
#     240                                   prefer_static_value=prefer_static_value)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/bijectors/bijector.py in _composite_tensor_shape_params(self)
#    1920     """
#    1921     try:
# -> 1922       return tuple(k for k, v in self.parameter_properties().items()
#    1923                    if v.specifies_shape)
#    1924     except NotImplementedError:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/bijectors/bijector.py in parameter_properties(cls, dtype)
#    1316     """
#    1317     with tf.name_scope('parameter_properties'):
# -> 1318       return cls._parameter_properties(dtype)
#    1319
#    1320   @classmethod
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/bijectors/scale_matvec_linear_operator.py in _parameter_properties(cls, dtype)
#      46   @classmethod
#      47   def _parameter_properties(cls, dtype):
# ---> 48     return dict(scale=parameter_properties.BatchedComponentProperties())
#      49
#      50   def _forward(self, x):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/internal/parameter_properties.py in __new__(cls, event_ndims, event_ndims_tensor, default_constraining_bijector_fn, is_preferred)
#     369         is_preferred=is_preferred,
#     370         is_tensor=False,
# --> 371         specifies_shape=False)
#     372
#     373
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/internal/parameter_properties.py in __new__(cls, event_ndims, event_ndims_tensor, shape_fn, default_constraining_bijector_fn, is_preferred, is_tensor, specifies_shape)
#     308         is_preferred=is_preferred,
#     309         is_tensor=is_tensor,
# --> 310         specifies_shape=specifies_shape)
#     311
#     312   def instance_event_ndims(self, instance, require_static=False):
#
# <string> in __new__(_cls, event_ndims, event_ndims_tensor, shape_fn, default_constraining_bijector_fn, is_preferred, is_tensor, specifies_shape)
#
# KeyboardInterrupt:

# %%
x = flow.sample(1000).numpy()
print(x.shape)
plt.scatter(x[:,0],x[:,1], c='r')
plt.show()
# Out:
# (1000, 2)

# %%
flow2 = RNVP(depth = 3, height = 6, prior_dim = 784, hidden_size = 512)

# %%
(train_images, _), (test_images, _) = tf.keras.datasets.mnist.load_data()
train_images = np.reshape(train_images, [train_images.shape[0], -1])
test_images = np.reshape(test_images, [test_images.shape[0],-1])
train_images = train_images / 255.0
test_images = test_images / 255.0

images = np.concatenate((train_images,test_images),axis=0)
images = tf.convert_to_tensor(images,dtype='float32')

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
for t in range(5001):   
    indices = np.random.choice(70000,1000,replace=False)
    batch_of_digits = tf.gather(images,indices)
    with tf.GradientTape() as tape:
      z, sldj = flow2.call(batch_of_digits)
      loss = flow2.loss_function(z, sldj)
    gradients = tape.gradient(loss, flow2.trainable_variables)
    optimizer.apply_gradients(zip(gradients, flow2.trainable_variables))
    
    if t % 200 == 0:
        print('iter %s:' % t, 'loss = %.3f' % loss)
        print(tf.reduce_mean(sldj))
# Out:
# iter 0: loss = 772.733
# tf.Tensor(-5.796398, shape=(), dtype=float32)
# iter 200: loss = -959.626
# tf.Tensor(1885.5781, shape=(), dtype=float32)
# iter 400: loss = -1071.370
# tf.Tensor(1967.2168, shape=(), dtype=float32)
# iter 600: loss = -1123.280
# tf.Tensor(2005.6532, shape=(), dtype=float32)
# iter 800: loss = -1164.183
# tf.Tensor(2033.6096, shape=(), dtype=float32)
# iter 1000: loss = -1194.369
# tf.Tensor(2052.8896, shape=(), dtype=float32)
# iter 1200: loss = -1216.127
# tf.Tensor(2066.0588, shape=(), dtype=float32)
# iter 1400: loss = -1232.370
# tf.Tensor(2079.1196, shape=(), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-cfc7b4fa6116> in <module>()
#       4     batch_of_digits = tf.gather(images,indices)
#       5     with tf.GradientTape() as tape:
# ----> 6       z, sldj = flow2.call(batch_of_digits)
#       7       loss = flow2.loss_function(z, sldj)
#       8     gradients = tape.gradient(loss, flow2.trainable_variables)
#
# <ipython-input-18-d7e38d377041> in call(self, x)
#      84             ## Update output_dist via the transformation described in equation (8) of this paper https://arxiv.org/pdf/1605.08803.pdf
#      85             ## We add the un-updated output_dist_masked to the updated output_dist multiplied by the reverse mask
# ---> 86             updated_dist = (output_dist-t_out) * tf.math.exp(-1 * s_out)
#      87             output_dist = output_dist_masked + reverse_mask * updated_dist
#      88             ## We also update the log of the determinant of the Jacobian at each step of the transformation according
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in r_binary_op_wrapper(y, x)
#    1415       # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1416       #   r_binary_op_wrapper use different force_same_dtype values.
# -> 1417       y, x = maybe_promote_tensors(y, x)
#    1418       return func(x, y, name=name)
#    1419
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in maybe_promote_tensors(force_same_dtype, *tensors)
#    1348     for tensor in tensors[1:]:
#    1349       promoted_tensors.append(
# -> 1350           ops.convert_to_tensor(tensor, dtype, name="x"))
#    1351     return promoted_tensors
#    1352   result_type = np_dtypes._result_type(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1628           "%sConversion function %r for type %s returned non-Tensor: %r" %
#    1629           (_error_prefix(name), conversion_func, base_type, ret))
# -> 1630     if dtype and not dtype.is_compatible_with(ret.dtype):
#    1631       raise RuntimeError(
#    1632           "%sConversion function %r for type %s returned incompatible "
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py in is_compatible_with(self, other)
#     173       this `DType`.
#     174     """
# --> 175     other = as_dtype(other)
#     176     return self._type_enum in (other.as_datatype_enum,
#     177                                other.base_dtype.as_datatype_enum)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py in as_dtype(type_value)
#     700   """
#     701   if isinstance(type_value, DType):
# --> 702     return _INTERN_TABLE[type_value.as_datatype_enum]
#     703
#     704   if isinstance(type_value, np.dtype):
#
# KeyboardInterrupt:

# %%
x = flow2.sample(10)

# %%
def show_images(images):
    images = np.reshape(images, [images.shape[0], -1])  # images reshape to (batch_size, D)
    images = images/255.0
    sqrtn = int(np.ceil(np.sqrt(images.shape[0])))
    sqrtimg = int(np.ceil(np.sqrt(images.shape[1])))

    fig = plt.figure(figsize=(sqrtn, sqrtn))
    gs = gridspec.GridSpec(sqrtn, sqrtn)
    gs.update(wspace=0.05, hspace=0.05)

    for i, img in enumerate(images):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        plt.imshow(img.reshape([sqrtimg,sqrtimg]),cmap='gray')
    return

# %%
show_images(x)
